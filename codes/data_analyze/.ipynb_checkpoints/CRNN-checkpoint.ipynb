# %%
import numpy as np
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ## 图像处理工具

# %%
image = cv2.imread('D:\\radar_pull\\OpencvTest\\OpencvTest\\443.png')
image2 =  cv2.imread('D:\\radar_pull\\OpencvTest\\OpencvTest\\444.png')

# %%
plt.figure(figsize=(10, 10), dpi=150)
plt.imshow(image)
image.shape
# Out:
# (920, 920, 3)

# %%
def down_image(image):
    return cv2.pyrDown(cv2.pyrDown(image))

plt.figure(figsize=(5, 5), dpi=150)
image = down_image(image)
plt.imshow(image)
image.shape
# Out:
# (230, 230, 3)

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image[278][227]
# Out:
# array([255, 255, 255], dtype=uint8)
